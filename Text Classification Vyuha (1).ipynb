# %%
cd C:\\Users\\bunny\\Desktop  # Setting Directory
# Out:
# C:\Users\bunny\Desktop

# %% [markdown]
# As our sample corpus of text, collected data is read using readlines function. These articles have been stored in a single file, so that one article appears on each line.

# %%
fin = open("sample.txt","r")
raw_documents = fin.readlines()
fin.close()
#print("Read %d raw text documents" % len(raw_documents))

# %% [markdown]
# # Tokenizing text

# %% [markdown]
# In the below code, used the built-in scikit-learn tokenizer to split the document into tokens. And then performed case conversion first to convert the entire text to lowercase. Then used stop words list from scikit learn to remove words that re not useful.

# %%
from sklearn.feature_extraction.text import CountVectorizer
tokenize = CountVectorizer().build_tokenizer()

from sklearn.feature_extraction import text
stopwords = text.ENGLISH_STOP_WORDS

all_filtered_tokens = []
for doc in raw_documents:
    # tokenize the next document
    tokens = tokenize(doc.lower())
    # remove the stopwords
    filtered_tokens = []
    for token in tokens:
        if not token in stopwords:
            filtered_tokens.append(token)  
    # add to the overall list
    all_filtered_tokens.append( filtered_tokens )

# %% [markdown]
# Document Term matrix:
#
# since each document can be represented as a term vector, stacking these vectors to create a document-term matrix. This is created using list of document strings from package scikit learn.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(raw_documents)

# %%
terms = vectorizer.get_feature_names()
vocab = vectorizer.vocabulary_
print("Vocabulary has %d distinct terms" % len(terms))
# Out:
# Vocabulary has 23596 distinct terms

# %%
print(terms[500:530])
vocab
# Out:
# ['10 there', '10 this', '10 times', '10 to', '10 together', '10 took', '10 trucks', '10 us', '10 victory', '10 was', '10 week', '10 weeks', '10 were', '10 which', '10 while', '10 win', '10 with', '10 world', '10 xbox', '10 yards', '10 year', '10 years', '100', '100 000', '100 53', '100 again', '100 and', '100 but', '100 companies', '100 countries']
# {'the': 214091,
#  'sporting': 201906,
#  'industry': 112776,
#  'has': 99929,
#  'come': 52109,
#  'long': 130699,
#  'way': 240722,
#  'since': 196753,
#  '60s': 6376,
#  'it': 118391,
#  'carved': 45994,
#  'out': 160095,
#  'for': 85305,
#  'itself': 120205,
#  'niche': 147823,
#  'with': 246907,
#  'its': 119399,
#  'roots': 185272,
#  'so': 198660,
#  'deep': 62871,
#  'that': 212630,
#  'cannot': 44867,
#  'fathom': 80346,
#  'sports': 201926,
#  'showing': 195622,
#  'any': 21326,
#  'sign': 196122,
#  'of': 150893,
#  'decline': 62758,
#  'time': 223556,
#  'soon': 200090,
#  'or': 158204,
#  'later': 125671,
#  'reason': 178137,
#  'can': 44401,
#  'be': 30754,
#  'found': 87806,
#  'in': 109588,
#  'this': 221728,
#  'seemingly': 191864,
#  'subtle': 206419,
#  'difference': 65673,
#  'other': 159307,
#  'industries': 112746,
#  'have': 100749,
#  'customers': 60350,
#  'fans': 79840,
#  'vivek': 238086,
#  'ranadivé': 176717,
#  'leader': 126407,
#  'ownership': 161722,
#  'group': 97140,
#  'nba': 145647,
#  'sacramento': 186804,
#  'kings': 123788,
#  'explained': 78229,
#  'beautifully': 32133,
#  'will': 245539,
#  'paint': 162120,
#  'their': 219185,
#  'face': 78954,
#  'purple': 174950,
#  'evangelize': 76151,
#  'every': 76631,
#  'ceo': 47006,
#  'business': 41097,
#  'is': 116713,
#  'dying': 70595,
#  'to': 224281,
#  'our': 159789,
#  'position': 169420,
#  'they': 220929,
#  're': 177345,
#  'while': 244376,
#  'fan': 79795,
#  'passion': 163273,
#  'alone': 14072,
#  'could': 57548,
#  'almost': 13938,
#  'certainly': 47092,
#  'keep': 122842,
#  'going': 95127,
#  'leagues': 126717,
#  'and': 16650,
#  'franchises': 88419,
#  'decided': 62545,
#  'not': 148894,
#  'rest': 182473,
#  'on': 155420,
#  'laurels': 126055,
#  'last': 125467,
#  'few': 81449,
#  'years': 251246,
#  'seen': 191889,
#  'steady': 203780,
#  'introduction': 115591,
#  'technology': 210864,
#  'into': 115221,
#  'world': 249254,
#  'amplifying': 15797,
#  'appreciation': 22218,
#  'games': 91748,
#  'enhancing': 74210,
#  'athletes': 26976,
#  'public': 174540,
#  'profiles': 172806,
#  'informing': 113292,
#  'training': 229176,
#  'methods': 138522,
#  'even': 76180,
#  'influencing': 113148,
#  'how': 106911,
#  'contests': 56006,
#  'are': 22553,
#  'waged': 238494,
#  'also': 14349,
#  'digital': 65948,
#  'particular': 162853,
#  'helped': 103096,
#  'create': 58646,
#  'an': 15845,
#  'alternative': 14924,
#  'source': 200345,
#  'revenue': 183191,
#  'besides': 34698,
#  'themselves': 220229,
#  'corporate': 57103,
#  'sponsorship': 201769,
#  'achieved': 9117,
#  'by': 42345,
#  'capitalizing': 45125,
#  'ardor': 22549,
#  'customer': 60324,
#  'base': 30213,
#  'sorry': 200197,
#  'return': 183019,
#  'article': 24225,
#  'search': 190595,
#  'results': 182697,
#  'the sporting': 218330,
#  'sporting industry': 201921,
#  'industry has': 112831,
#  'has come': 100065,
#  'come long': 52143,
#  'long way': 130783,
#  'way since': 240817,
#  'since the': 196895,
#  'the 60s': 214275,
#  '60s it': 6377,
#  'it has': 118727,
#  'has carved': 100044,
#  'carved out': 45995,
#  'out for': 160178,
#  'for itself': 86034,
#  'itself niche': 120238,
#  'niche with': 147832,
#  'with its': 247528,
#  'its roots': 120037,
#  'roots so': 185277,
#  'so deep': 198701,
#  'deep that': 62892,
#  'that cannot': 212853,
#  'cannot fathom': 44882,
#  'fathom the': 80347,
#  'the sports': 218331,
#  'sports industry': 201960,
#  'industry showing': 112883,
#  'showing any': 195626,
#  'any sign': 21539,
#  'sign of': 196142,
#  'of decline': 151749,
#  'decline any': 62760,
#  'any time': 21568,
#  'time soon': 223776,
#  'soon or': 200115,
#  'or later': 158520,
#  'later the': 125723,
#  'the reason': 217761,
#  'reason can': 178140,
#  'can be': 44431,
#  'be found': 31176,
#  'found in': 87842,
#  'in this': 111183,
#  'this seemingly': 222082,
#  'seemingly subtle': 191867,
#  'subtle difference': 206421,
#  'difference other': 65688,
#  'other industries': 159475,
#  'industries have': 112755,
#  'have customers': 100921,
#  'customers the': 60413,
#  'has fans': 100178,
#  'fans vivek': 79910,
#  'vivek ranadivé': 238088,
#  'ranadivé leader': 176718,
#  'leader of': 126425,
#  'of the': 153649,
#  'the ownership': 217292,
#  'ownership group': 161728,
#  'group of': 97256,
#  'the nba': 217088,
#  'nba sacramento': 145652,
#  'sacramento kings': 186805,
#  'kings explained': 123793,
#  'explained it': 78235,
#  'it beautifully': 118466,
#  'beautifully fans': 32134,
#  'fans will': 79917,
#  'will paint': 245840,
#  'paint their': 162124,
#  'their face': 219439,
#  'face purple': 79037,
#  'purple fans': 174951,
#  'will evangelize': 245692,
#  'evangelize every': 76152,
#  'every other': 76682,
#  'other ceo': 159352,
#  'ceo in': 47011,
#  'in every': 110199,
#  'every business': 76640,
#  'business is': 41165,
#  'is dying': 117089,
#  'dying to': 70598,
#  'to be': 224716,
#  'be in': 31264,
#  'in our': 110703,
#  'our position': 159972,
#  'position they': 169452,
#  'they re': 221173,
#  're dying': 177381,
#  'to have': 225568,
#  'have fans': 101002,
#  'fans while': 79915,
#  'while fan': 244463,
#  'fan passion': 79805,
#  'passion alone': 163274,
#  'alone could': 14082,
#  'could almost': 57556,
#  'almost certainly': 13979,
#  'certainly keep': 47116,
#  'keep the': 122911,
#  'the industry': 216404,
#  'industry going': 112828,
#  'going leagues': 95163,
#  'leagues and': 126719,
#  'and sporting': 19779,
#  'sporting franchises': 201915,
#  'franchises have': 88420,
#  'have decided': 100926,
#  'decided not': 62555,
#  'not to': 149482,
#  'to rest': 226450,
#  'rest on': 182488,
#  'on their': 156264,
#  'their laurels': 219582,
#  'laurels the': 126056,
#  'the last': 216657,
#  'last few': 125506,
#  'few years': 81529,
#  'years have': 251310,
#  'have seen': 101353,
#  'seen the': 191959,
#  'the steady': 218386,
#  'steady introduction': 203785,
#  'introduction of': 115594,
#  'of technology': 153630,
#  'technology into': 210953,
#  'into the': 115491,
#  'the world': 219103,
#  'world of': 249407,
#  'of sports': 153478,
#  'sports amplifying': 201929,
#  'amplifying fans': 15798,
#  'fans appreciation': 79844,
#  'appreciation of': 22219,
#  'of games': 152139,
#  'games enhancing': 91800,
#  'enhancing athletes': 74211,
#  'athletes public': 27007,
#  'public profiles': 174604,
#  'profiles and': 172807,
#  'and informing': 18349,
#  'informing their': 113296,
#  'their training': 219907,
#  'training methods': 229207,
#  'methods even': 138524,
#  'even influencing': 76245,
#  'influencing how': 113149,
#  'how contests': 106931,
#  'contests are': 56007,
#  'are waged': 23414,
#  'waged also': 238495,
#  'also digital': 14482,
#  'digital technology': 66039,
#  'technology in': 210947,
#  'in particular': 110728,
#  'particular has': 162868,
#  'has helped': 100230,
#  'helped to': 103147,
#  'to create': 225036,
#  'create an': 58650,
#  'an alternative': 15926,
#  'alternative source': 14941,
#  'source of': 200362,
#  'of revenue': 153230,
#  'revenue besides': 183194,
#  'besides the': 34699,
#  'the games': 216056,
#  'games themselves': 91914,
#  'themselves corporate': 220239,
#  'corporate sponsorship': 57145,
#  'sponsorship they': 201779,
#  'they achieved': 220934,
#  'achieved this': 9134,
#  'this by': 221781,
#  'by capitalizing': 42563,
#  'capitalizing on': 45126,
#  'on the': 156263,
#  'the ardor': 214493,
#  'ardor of': 22550,
#  'of their': 153650,
#  'their customer': 219356,
#  'customer base': 60327,
#  'base sorry': 30226,
#  'sorry fan': 200199,
#  'fan base': 79800,
#  'base return': 30225,
#  'return to': 183052,
#  'to article': 224646,
#  'article search': 24231,
#  'search results': 190638,
#  'asian': 25506,
#  'quake': 175375,
#  'hits': 105479,
#  'european': 75838,
#  'sharesshares': 194296,
#  'europe': 75692,
#  'leading': 126484,
#  'reinsurers': 180141,
#  'travel': 229513,
#  'firms': 83515,
#  'fallen': 79565,
#  'as': 24312,
#  'scale': 189395,
#  'damage': 60887,
#  'wrought': 250391,
#  'tsunamis': 230475,
#  'across': 9268,
#  'south': 200403,
#  'asia': 25456,
#  'become': 32349,
#  'apparent': 21852,
#  'more': 141760,
#  'than': 212183,
#  '23': 3698,
#  '000': 5,
#  'people': 164553,
#  'been': 32526,
#  'killed': 123672,
#  'following': 84957,
#  'massive': 135655,
#  'underwater': 232670,
#  'earthquake': 71049,
#  'many': 134355,
#  'worst': 249735,
#  'hit': 105366,
#  'areas': 23495,
#  'popular': 169071,
#  'tourist': 228461,
#  'destinations': 64747,
#  'reisurance': 180152,
#  'such': 206612,
#  'swiss': 208656,
#  'munich': 144123,
#  'lost': 131274,
#  'value': 236101,
#  'investors': 115908,
#  'worried': 249631,
#  'about': 7922,
#  'rebuilding': 178256,
#  'costs': 57432,
#  'but': 41352,
#  'disaster': 66558,
#  'little': 129735,
#  'impact': 109027,
#  'stock': 204486,
#  'markets': 135314,
#  'us': 234555,
#  'currencies': 59980,
#  'including': 111675,
#  'thai': 212141,
#  'baht': 29154,
#  'indonesian': 112639,
#  'rupiah': 186450,
#  'weakened': 241197,
#  'analysts': 16529,
#  'warned': 239133,
#  'economic': 71418,
#  'growth': 97493,
#  'may': 136245,
#  'slow': 198032,
#  'came': 44106,
#  'at': 26020,
#  'possible': 169591,
#  'said': 186955,
#  'hans': 99329,
#  'goetti': 95122,
#  'singapore': 196928,
#  'based': 30235,
#  'fund': 90548,
#  'manager': 133972,
#  'pretty': 171148,
#  'devastating': 64972,
#  'especially': 75214,
#  'thailand': 212146,
#  'related': 180224,
#  'shares': 194208,
#  'dropped': 69778,
#  'companies': 52911,
#  'germany': 93140,
#  'tui': 230599,
#  'lufthansa': 131813,
#  'france': 88244,
#  'club': 50937,
#  'mediterranne': 137524,
#  'sliding': 197865,
#  'insurers': 114315,
#  'reinsurance': 180133,
#  'were': 242449,
#  'under': 232336,
#  'pressure': 171031,
#  'two': 231191,
#  'biggest': 35654,
#  'both': 38075,
#  'fell': 81108,
#  'market': 135001,
#  'speculated': 201140,
#  'cost': 57303,
#  'zurich': 252672,
#  'financial': 82615,
#  'allianz': 13739,
#  'axa': 28582,
#  'suffered': 206857,
#  'however': 107054,
#  'losses': 131236,
#  'much': 143817,
#  'smaller': 198288,
#  'reflecting': 179576,
#  'view': 237409,
#  'likely': 128947,
#  'pick': 166384,
#  'up': 233836,
#  'bulk': 40765,
#  'worries': 249644,
#  'size': 197469,
#  'insurance': 114263,
#  'liabilities': 128159,
#  'dragged': 69254,
#  'down': 68833,
#  'although': 14951,
#  'was': 239297,
#  'exacerbated': 76976,
#  'light': 128568,
#  'post': 169696,
#  'christmas': 49421,
#  'trading': 228913,
#  'benchmark': 34376,
#  'dax': 61594,
#  'index': 112233,
#  'closed': 50784,
#  'day': 61598,
#  '16': 1507,
#  '29': 4216,
#  'points': 168528,
#  'lower': 131561,
#  '817': 7206,
#  '69': 6609,
#  'cac': 43576,
#  '07': 323,
#  'pointed': 168510,
#  'declines': 62794,
#  'probably': 171960,
#  'would': 249839,
#  'specific': 201051,
#  'hardest': 99649,
#  'still': 204189,
#  'too': 227533,
#  'early': 70822,
#  'concrete': 54428,
#  'figures': 81930,
#  'spokesman': 201683,
#  'floiran': 84606,
#  'woest': 248479,
#  'told': 227320,
#  'associated': 25866,
#  'press': 170954,
#  'do': 67590,
#  'fact': 79217,
#  'very': 236789,
#  'widely': 245350,
#  'spread': 202091,
#  'geographically': 92993,
#  'unfolding': 232838,
#  'had': 98074,
#  'immediate': 108914,
#  'dow': 68824,
#  'jones': 121648,
#  'risen': 184108,
#  '20': 2471,
#  '54': 6016,
#  '10': 366,
#  '847': 7273,
#  '66': 6528,
#  'late': 125611,
#  'morning': 142359,
#  'analsyts': 16454,
#  'cheered': 48484,
#  'encouraging': 73428,
#  'reports': 181572,
#  'from': 89154,
#  'retailers': 182847,
#  'sales': 188116,
#  'adjustments': 10123,
#  'made': 132272,
#  'quickly': 175832,
#  'account': 8860,
#  'earnings': 70979,
#  'repairs': 181114,
#  'airways': 12868,
#  'shed': 194632,
#  'country': 58004,
#  'relies': 180559,
#  'tourism': 228439,
#  'total': 228053,
#  'economy': 71621,
#  'airlines': 12794,
#  'annual': 20848,
#  'gross': 97052,
#  'domestic': 68193,
#  'product': 172487,
#  'gdp': 92590,
#  'comes': 52214,
#  'malaysia': 133681,
#  'budget': 40503,
#  'airline': 12725,
#  'airasia': 12654,
#  'resort': 182247,
#  'operator': 157849,
#  'tanco': 209852,
#  'holdings': 105778,
#  'slumped': 198181,
#  'took': 227659,
#  'japan': 120661,
#  'kinki': 123806,
#  'nippon': 148137,
#  'his': 104591,
#  'dropping': 69827,
#  'overall': 161050,
#  'largest': 125325,
#  'nikkei': 148031,
#  'slight': 197870,
#  'just': 122271,
#  '03': 261,
#  'concerns': 54340,
#  'strength': 205229,
#  'forward': 87657,
#  'weighed': 242039,
#  'currency': 59990,
#  'against': 11575,
#  'dollar': 68039,
#  'before': 33265,
#  'bouncing': 38404,
#  'back': 28679,
#  'slightly': 197885,
#  'trade': 228787,
#  '300': 4457,
#  '39': 4961,
#  'india': 112280,
#  'where': 243686,
#  'thought': 222536,
#  'died': 65627,
#  'rupee': 186416,
#  'difficult': 65852,
#  'predict': 170397,
#  'share': 194005,
#  'prices': 171480,
#  'increasing': 112033,
#  'bills': 35933,
#  'mounted': 142878,
#  'comments': 52407,
#  'asian quake': 25526,
#  'quake hits': 175381,
#  'hits european': 105483,
#  'european sharesshares': 75964,
#  'sharesshares in': 194297,
#  'in europe': 110195,
#  'europe leading': 75766,
#  'leading reinsurers': 126536,
#  'reinsurers and': 180142,
#  'and travel': 20066,
#  'travel firms': 229528,
#  'firms have': 83573,
#  'have fallen': 101000,
#  'fallen as': 79573,
#  'as the': 25249,
#  'the scale': 218032,
#  'scale of': 189411,
#  'the damage': 215338,
#  'damage wrought': 60921,
#  'wrought by': 250392,
#  'by tsunamis': 43377,
#  'tsunamis across': 230476,
#  'across south': 9302,
#  'south asia': 200411,
#  'asia has': 25475,
#  'has become': 100018,
#  'become apparent': 32355,
#  'apparent more': 21857,
#  'more than': 142229,
#  'than 23': 212218,
#  '23 000': 3699,
#  '000 people': 127,
#  'people have': 164682,
#  'have been': 100833,
#  'been killed': 32870,
#  'killed following': 123680,
#  'following massive': 84995,
#  'massive underwater': 135714,
#  'underwater earthquake': 232672,
#  'earthquake and': 71050,
#  'and many': 18686,
#  'many of': 134504,
#  'the worst': 219111,
#  'worst hit': 249746,
#  'hit areas': 105374,
#  'areas are': 23497,
#  'are popular': 23154,
#  'popular tourist': 169130,
#  'tourist destinations': 228466,
#  'destinations reisurance': 64750,
#  'reisurance firms': 180153,
#  'firms such': 83627,
#  'such as': 206622,
#  'as swiss': 25230,
#  'swiss re': 208668,
#  're and': 177355,
#  'and munich': 18830,
#  'munich re': 144132,
#  're lost': 177418,
#  'lost value': 131371,
#  'value as': 236109,
#  'as investors': 24819,
#  'investors worried': 115980,
#  'worried about': 249632,
#  'about rebuilding': 8243,
#  'rebuilding costs': 178260,
#  'costs but': 57450,
#  'but the': 42006,
#  'the disaster': 215488,
#  'disaster has': 66563,
#  'has little': 100304,
#  'little impact': 129777,
#  'impact on': 109045,
#  'on stock': 156228,
#  'stock markets': 204501,
#  'markets in': 135339,
#  'in the': 111171,
#  'the us': 218874,
#  'us and': 234596,
#  'and asia': 16936,
#  'asia currencies': 25468,
#  'currencies including': 59983,
#  'including the': 111783,
#  'the thai': 218624,
#  'thai baht': 212143,
#  'baht and': 29157,
#  'and indonesian': 18335,
#  'indonesian rupiah': 112646,
#  'rupiah weakened': 186456,
#  'weakened as': 241199,
#  'as analysts': 24373,
#  'analysts warned': 16605,
#  'warned that': 239169,
#  'that economic': 213056,
#  'economic growth': 71469,
#  'growth may': 97559,
#  'may slow': 136373,
#  'slow it': 198050,
#  'it came': 118513,
#  'came at': 44115,
#  'at the': 26810,
#  'worst possible': 249756,
#  'possible time': 169674,
#  'time said': 223757,
#  'said hans': 187341,
#  'hans goetti': 99332,
#  'goetti singapore': 95123,
#  'singapore based': 196932,
#  'based fund': 30303,
#  'fund manager': 90567,
#  'manager the': 134066,
#  'the impact': 216360,
#  'the tourist': 218702,
#  'tourist industry': 228467,
#  'industry is': 112839,
#  'is pretty': 117625,
#  'pretty devastating': 171153,
#  'devastating especially': 64975,
#  'especially in': 75233,
#  'in thailand': 111168,
#  'thailand travel': 212169,
#  'travel related': 229547,
#  'related shares': 180237,
#  'shares dropped': 194228,
#  'dropped in': 69802,
#  'europe with': 75833,
#  'with companies': 247172,
#  'companies such': 53031,
#  'as germany': 24722,
#  'germany tui': 93210,
#  'tui and': 230600,
#  'and lufthansa': 18646,
#  'lufthansa and': 131815,
#  'and france': 18005,
#  'france club': 88276,
#  'club mediterranne': 51031,
#  'mediterranne sliding': 137525,
#  'sliding insurers': 197868,
#  'insurers and': 114317,
#  'and reinsurance': 19384,
#  'reinsurance firms': 180137,
#  'firms were': 83647,
#  'were also': 242492,
#  'also under': 14873,
#  'under pressure': 232441,
#  'pressure in': 171054,
#  'europe shares': 75800,
#  'shares in': 194245,
#  'in munich': 110635,
#  'and swiss': 19906,
#  're the': 177465,
#  'world two': 249485,
#  'two biggest': 231214,
#  'biggest reinsurers': 35765,
#  'reinsurers both': 180143,
#  'both fell': 38143,
#  'fell as': 81126,
#  'the market': 216867,
#  'market speculated': 135210,
#  'speculated about': 201141,
#  'about the': 8302,
#  'the cost': 215249,
#  'cost of': 57363,
#  'of rebuilding': 153154,
#  'rebuilding in': 178263,
#  'in asia': 109795,
#  'asia zurich': 25505,
#  'zurich financial': 252675,
#  'financial allianz': 82622,
#  'allianz and': 13740,
#  'and axa': 16985,
#  'axa also': 28583,
#  'also suffered': 14831,
#  'suffered decline': 206868,
#  'decline in': 62771,
#  'in value': 111266,
#  'value however': 236121,
#  'however their': 107206,
#  'their losses': 219606,
#  'losses were': 131262,
#  'were much': 242776,
#  'much smaller': 143930,
#  'smaller reflecting': 198321,
#  'reflecting the': 179581,
#  'market view': 135245,
#  'view that': 237430,
#  'that reinsurers': 213683,
#  'reinsurers were': 180145,
#  'were likely': 242746,
#  'likely to': 128979,
#  'to pick': 226185,
#  'pick up': 166401,
#  'up the': 234166,
#  'the bulk': 214845,
#  'bulk of': 40769,
#  'the costs': 215251,
#  'costs worries': 57514,
#  'worries about': 249645,
#  'the size': 218226,
#  'size of': 197479,
#  'of insurance': 152377,
#  'insurance liabilities': 114289,
#  'liabilities dragged': 128161,
#  'dragged european': 69257,
#  'european shares': 75963,
#  'shares down': 194227,
#  'down although': 68854,
#  'although the': 15037,
#  'impact was': 109058,
#  'was exacerbated': 239631,
#  'exacerbated by': 76977,
#  'by light': 42961,
#  'light post': 128592,
#  'post christmas': 169709,
#  'christmas trading': 49475,
#  'trading germany': 228934,
#  'germany benchmark': 93155,
#  'benchmark dax': 34380,
#  'dax index': 61595,
#  'index closed': 112235,
#  'closed the': 50813,
#  'the day': 215359,
#  'day 16': 61599,
#  '16 29': 1510,
#  '29 points': 4238,
#  'points lower': 168571,
#  'lower at': 131564,
#  'at 817': 26152,
#  '817 69': 7207,
#  '69 while': 6617,
#  'while france': 244473,
#  'france cac': 88269,
#  'cac index': 43577,
#  'index of': 112255,
#  'of leading': 152524,
#  'leading shares': 126544,
#  'shares fell': 194231,
#  'fell 07': 81109,
#  '07 points': 325,
#  'points to': 168590,
#  'to 817': 224488,
#  '69 investors': 6615,
#  'investors pointed': 115956,
#  'pointed out': 168511,
#  'out however': 160200,
#  'however that': 107204,
#  'that declines': 212988,
#  'declines probably': 62797,
#  'probably would': 172019,
#  'would be': 249864,
#  'be industry': 31272,
#  'industry specific': 112888,
#  'specific with': 201073,
#  'with the': 248050,
#  'the travel': 218740,
#  'travel and': 229517,
#  'and insurance': 18369,
#  'insurance firms': 114286,
#  'firms hit': 83575,
#  'hit hardest': 105400,
#  'hardest it': 99654,
#  'it still': 119075,
#  'still too': 204389,
#  'too early': 227564,
#  'early for': 70851,
#  'for concrete': 85627,
#  'concrete damage': 54429,
#  'damage figures': 60900,
#  'figures swiss': 82000,
#  're spokesman': 177456,
#  'spokesman floiran': 201696,
#  'floiran woest': 84607,
#  'woest told': 248480,
#  'told associated': 227329,
#  'associated press': 25868,
#  'press that': 171001,
#  'that also': 212708,
#  'also has': 14563,
#  'has to': 100598,
#  'to do': 225171,
#  'do with': 67728,
#  'the fact': 215795,
#  'fact that': 79242,
#  'that the': 213901,
#  'damage is': 60907,
#  'is very': 118013,
#  'very widely': 236979,
#  'widely spread': 245378,
#  'spread geographically': 202103,
#  'geographically the': 92994,
#  'the unfolding': 218825,
#  'unfolding scale': 232839,
#  'disaster in': 66566,
#  'in south': 111058,
#  'asia had': 25474,
#  'had little': 98320,
#  'little immediate': 129776,
#  'immediate impact': 108921,
#  'on us': 156317,
#  'us shares': 234968,
#  'shares however': 194243,
#  'however the': 107205,
#  'the dow': 215546,
#  'dow jones': 68825,
#  'jones index': 121679,
#  'index had': 112246,
#  'had risen': 98440,
#  'risen 20': 184110,
#  '20 54': 2482,
#  '54 points': 6026,
#  'points or': 168579,
#  'or to': 158766,
#  'to 10': 224289,
#  '10 847': 395,
#  '847 66': 7274,
#  '66 by': 6531,
#  'by late': 42951,
#  'late morning': 125644,
#  'morning as': 142364,
#  'as analsyts': 24372,
#  'analsyts were': 16455,
#  'were cheered': 242554,
#  'cheered by': 48485,
#  'by more': 43027,
#  'more encouraging': 141920,
#  'encouraging reports': 73440,
#  'reports from': 181588,
#  'from retailers': 89878,
#  'retailers about': 182848,
#  'about post': 8224,
#  'christmas sales': 49465,
#  'sales in': 188171,
#  'in asian': 109796,
#  'asian markets': 25523,
#  'markets adjustments': 135316,
#  'adjustments were': 10128,
#  'were made': 242761,
#  'made quickly': 132411,
#  'quickly to': 175880,
#  'to account': 224531,
#  'account for': 8873,
#  'for lower': 86117,
#  'lower earnings': 131575,
#  'earnings and': 70981,
#  'and the': 19974,
#  'of repairs': 153194,
#  'repairs thai': 181116,
#  'thai airways': 212142,
#  'airways shed': 12882,
#  'shed almost': 194636,
#  'almost the': 14037,
#  'the country': 215257,
#  'country relies': 58127,
#  'relies on': 180562,
#  'on tourism': 156291,
#  'tourism for': 228447,
#  'for about': 85391,
#  'about of': 8206,
#  'of its': 152432,
#  'its total': 120147,
#  'total economy': 228079,
#  'economy singapore': 71721,
#  'singapore airlines': 196929,
#  'airlines dropped': 12805,
#  'dropped about': 69784,
#  'of singapore': 153402,
#  'singapore annual': 196931,
#  'annual gross': 20870,
#  'gross domestic': 97054,
#  'domestic product': 68223,
#  'product gdp': 172504,
#  'gdp comes': 92594,
#  'comes from': 52230,
#  'from tourism': 90030,
#  'tourism malaysia': 228450,
#  'malaysia budget': 133684,
#  'budget airline': 40505,
#  'airline airasia': 12729,
#  'airasia fell': 12655,
#  'fell resort': 81146,
#  'resort operator': 182249,
#  'operator tanco': 157871,
#  'tanco holdings': 209853,
#  'holdings slumped': 105789,
#  'slumped travel': 198183,
#  'travel companies': 229523,
#  'companies also': 52923,
#  'also took': 14861,
#  'took hit': 227695,
#  'hit with': 105461,
#  'with japan': 247532,
#  'japan kinki': 120713,
#  'kinki nippon': 123807,
#  'nippon sliding': 148139,
#  'sliding and': 197866,
#  'and his': 18232,
#  'his dropping': 104798,
#  'dropping however': 69830,
#  'the overall': 217282,
#  'overall impact': 161075,
#  'on asia': 155491,
#  'asia largest': 25480,
#  'largest stock': 125402,
#  'stock market': 204500,
#  'market japan': 135113,
#  'japan nikkei': 120720,
#  'nikkei was': 148035,
#  'was slight': 240169,
#  'slight shares': 197882,
#  'fell just': 81138,
#  ...}

# %% [markdown]
# # Text Preprocessing

# %% [markdown]
# Here, used the built-in list of stop-words for a given language by specifying the name of the language (lower-case) i.e; english.

# %%
vectorizer = CountVectorizer(stop_words="english")
X = vectorizer.fit_transform(raw_documents)
# Are standard stopwords gone?
"and" in vectorizer.vocabulary_
# Out:
# False

# %% [markdown]
# Removing low frequency terms that appear in fewer than a specified number of documents.

# %%
vectorizer = CountVectorizer(min_df = 5)
X = vectorizer.fit_transform(raw_documents)
print("Number of terms in model is %d" % len(vectorizer.vocabulary_) )
# Out:
# Number of terms in model is 7036

# %% [markdown]
# Performing lemmatisation using NLTK with scikit learn

# %%
import nltk
def lemma_tokenizer(text):
    # use the standard scikit-learn tokenizer first
    standard_tokenizer = CountVectorizer().build_tokenizer()
    tokens = standard_tokenizer(text)
    # then use NLTK to perform lemmatisation on each token
    lemmatizer = nltk.stem.WordNetLemmatizer()
    lemma_tokens = []
    for token in tokens:
        lemma_tokens.append( lemmatizer.lemmatize(token) )
    return lemma_tokens

# %%
nltk.download('wordnet')  ### Download the appropriate packages.
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\bunny\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
vectorizer = CountVectorizer(stop_words="english",min_df = 3,tokenizer=lemma_tokenizer)
X = vectorizer.fit_transform(raw_documents)
print(X.shape)
print(list(vectorizer.vocabulary_.keys())[0:35])
# Out:
# (1409, 8697)
# ['sporting', 'industry', 'ha', 'come', 'long', 'way', '60', 'niche', 'root', 'deep', 'sport', 'showing', 'sign', 'decline', 'time', 'soon', 'later', 'reason', 'seemingly', 'difference', 'customer', 'fan', 'leader', 'ownership', 'group', 'nba', 'king', 'explained', 'paint', 'face', 'ceo', 'business', 'dying', 'position', 'passion']

# %% [markdown]
# # Term Weighing

# %% [markdown]
# Improving the document term matrix by giving more important weight to the more important terms. To do that, most common normalisation is term frequency–inverse document frequency (TF-IDF).

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
# we can pass in the same preprocessing parameters
vectorizer = TfidfVectorizer(stop_words="english",min_df = 5)
X = vectorizer.fit_transform(raw_documents)
# display some sample weighted values
X.shape
# Out:
# (1409, 6771)

# %% [markdown]
# Importing a CSV which contains three columns i.e; title of the article, category and article text.

# %%
import pandas as pd
df = pd.read_csv('category_title_text.csv')
#df
df.columns = ['title','category','text'] ### changing column names

# %% [markdown]
# Randomly splitting the complete dataset into a training test and a test set that 20% (0.2) of the data will be used for the test set.

# %%
from sklearn.model_selection import train_test_split
y=df.category
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.2)

# %% [markdown]
# Text preprocessing, tokenizing and filtering of stopwords are included in a high level component that is able to build a dictionary of features and transform documents to feature vectors
#
# Since each document can be represented as a term vector, stack these vectors to create a full document-term matrix and create this matrix from a list of document strings using Scikit-learn

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train.text)
X_train_counts.shape
# Out:
# (1126, 21485)

# %% [markdown]
# The below code is to reduce the weightage of more common words like (the, is, an etc.) which occurs in all the documents using TF-IDF i.e Term Frequency times inverse document frequency.

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (1126, 21485)

# %% [markdown]
# # Naive bayes classifier

# %% [markdown]
# After getting the features, train a classifier to try to predict the category of a post. To do that, implementing naïve Bayes classifier by using scikit-learn which has the multinomial variant.

# %%
from sklearn.naive_bayes import MultinomialNB
#y_train.reshape
clf = MultinomialNB().fit(X_train_tfidf, y_train)

# %% [markdown]
# # Building a Pipeline

# %% [markdown]
# Building a pipeline in order to make the vectorizer => transformer => classifier easier to work with with using pipeline class from scikit learn package.

# %%
from sklearn.pipeline import Pipeline
text_clf = Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                     ('clf', MultinomialNB()),
                        ])

# %% [markdown]
# Training the model with a command fit(...)

# %%
text_clf.fit(X_train.text, y_train)  
predictions = text_clf.predict(X_test.text)

# %% [markdown]
# Evaluation of the performance on the test set

# %%
import numpy as np
print(np.mean(predictions == y_test))
len(predictions)
# Out:
# 0.9716312056737588
# 282

# %% [markdown]
# we achieved 97.16% accuracy.

# %% [markdown]
# # Support Vector Machine (SVM)

# %% [markdown]
# Now classify using support vector machine (SVM) and compare the results of both algorithms. Here, changed the learner by plugging a different classifier object into our pipeline:

# %%
from sklearn.linear_model import SGDClassifier
text_clf_svm = Pipeline([('vect', CountVectorizer()),
                      ('tfidf', TfidfTransformer()),
                      ('clf-svm', SGDClassifier(loss='hinge', penalty='l2',
                                            alpha=1e-3, n_iter=5, random_state=42)),
 ])
_ = text_clf_svm.fit(X_train.text, y_train)
predicted_svm = text_clf_svm.predict(X_test.text)
np.mean(predicted_svm == y_test)
# Out:
# C:\Users\bunny\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# 0.9858156028368794

# %% [markdown]
# The accuracy we got is 98.58% and it is little better compared to naive bayes classification.

# %% [markdown]
# In the below code, calculatind the average accuracy across all folds and comparing the accuracies of both naive bayes and support vector machine methods.

# %%
from sklearn.model_selection import cross_val_score

acc_scores_NB = cross_val_score(text_clf, df.text, y, cv=2, scoring="accuracy")
print(acc_scores_NB)

acc_scores_svm = cross_val_score(text_clf_svm, df.text, y, cv=2, scoring="accuracy")
print(acc_scores_svm)
# Out:
# [0.96879433 0.95305832]
# C:\Users\bunny\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# C:\Users\bunny\Anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:117: DeprecationWarning: n_iter parameter is deprecated in 0.19 and will be removed in 0.21. Use max_iter and tol instead.
#   DeprecationWarning)
# [0.98297872 0.96870555]
